# %%
import pandas as pd
import json

# %%
with open("chessbuds_messages.json") as j:
    spot = json.load(j)

# %%
type(spot)
# Out:
# dict

# %%
spot.keys()
# Out:
# dict_keys(['participants', 'messages', 'title', 'is_still_participant', 'thread_type', 'thread_path', 'magic_words', 'joinable_mode'])

# %%
type(spot['participants'])
# Out:
# list

# %%
type(spot['messages'])
# Out:
# list

# %%
type(spot['title'])
# Out:
# str

# %%
type(spot['is_still_participant'])
# Out:
# bool

# %%
type(spot['thread_type'])
# Out:
# str

# %%
type(spot['thread_path'])
# Out:
# str

# %%
type(spot['magic_words'])
# Out:
# list

# %%
type(spot['joinable_mode'])
# Out:
# dict

# %%
spot['joinable_mode'].keys()
# Out:
# dict_keys(['mode', 'link'])

# %%
type(spot['joinable_mode']['mode'])
# Out:
# int

# %%
type(spot['joinable_mode']['link'])
# Out:
# str

# %%
chessbuds = pd.DataFrame(spot['messages'])
chessbuds.head()
# Out:
#     sender_name   timestamp_ms  \
# 0  Joanna Rusch  1666374933946
# 1   Chad Larson  1666373448613
# 2   Chad Larson  1666373216381
# 3   Scott Pence  1666373164883
# 4   Chad Larson  1666373111157
#
#                                              content  \
# 0  Maybe he just wants to ride the publicity for ...
# 1  To be fair to Hans....no one wants to be assoc...
# 2  He would have to prove he didn't cheat and tha...
# 3  Yeah, no way. You over shoot and hope to get a...
# 4  From what I see, I don't think he could win.  ...
#
#                                            reactions     type  is_unsent  \
# 0  [{'reaction': 'ð', 'actor': 'Chad Larson'},...  Generic      False
# 1  [{'reaction': 'ð', 'actor': 'Scott Pence'},...  Generic      False
# 2  [{'reaction': 'ð', 'actor': 'Scott Pence'},...  Generic      False
# 3  [{'reaction': 'ð', 'actor': 'Chad Larson'},...  Generic      False
# 4                                                NaN  Generic      False
#
# ...

# %%
cb = pd.DataFrame(spot['messages'])
cb['timestamp_ms'] = pd.to_datetime(cb['timestamp_ms'], unit='ms')
cb.head()
# Out:
#     sender_name            timestamp_ms  \
# 0  Joanna Rusch 2022-10-21 17:55:33.946
# 1   Chad Larson 2022-10-21 17:30:48.613
# 2   Chad Larson 2022-10-21 17:26:56.381
# 3   Scott Pence 2022-10-21 17:26:04.883
# 4   Chad Larson 2022-10-21 17:25:11.157
#
#                                              content  \
# 0  Maybe he just wants to ride the publicity for ...
# 1  To be fair to Hans....no one wants to be assoc...
# 2  He would have to prove he didn't cheat and tha...
# 3  Yeah, no way. You over shoot and hope to get a...
# 4  From what I see, I don't think he could win.  ...
#
#                                            reactions     type  is_unsent  \
# 0  [{'reaction': 'ð', 'actor': 'Chad Larson'},...  Generic      False
# 1  [{'reaction': 'ð', 'actor': 'Scott Pence'},...  Generic      False
# 2  [{'reaction': 'ð', 'actor': 'Scott Pence'},...  Generic      False
# 3  [{'reaction': 'ð', 'actor': 'Chad Larson'},...  Generic      False
# ...

# %%
formatted_cb = pd.melt(cb,['sender_name'])
formatted_cb = formatted_cb.sort_values(by=['sender_name'])
cb.head()
# Out:
#     sender_name            timestamp_ms  \
# 0  Joanna Rusch 2022-10-21 17:55:33.946
# 1   Chad Larson 2022-10-21 17:30:48.613
# 2   Chad Larson 2022-10-21 17:26:56.381
# 3   Scott Pence 2022-10-21 17:26:04.883
# 4   Chad Larson 2022-10-21 17:25:11.157
#
#                                              content  \
# 0  Maybe he just wants to ride the publicity for ...
# 1  To be fair to Hans....no one wants to be assoc...
# 2  He would have to prove he didn't cheat and tha...
# 3  Yeah, no way. You over shoot and hope to get a...
# 4  From what I see, I don't think he could win.  ...
#
#                                            reactions     type  is_unsent  \
# 0  [{'reaction': 'ð', 'actor': 'Chad Larson'},...  Generic      False
# 1  [{'reaction': 'ð', 'actor': 'Scott Pence'},...  Generic      False
# 2  [{'reaction': 'ð', 'actor': 'Scott Pence'},...  Generic      False
# 3  [{'reaction': 'ð', 'actor': 'Chad Larson'},...  Generic      False
# ...

# %%
chessbuds2 = pd.DataFrame(spot['participants'])
chessbuds2.head()
# Out:
#                    name
# 0           Scott Pence
# 1           Chad Larson
# 2          Joanna Rusch
# 3  Angela Babbitt Pence
# 4           David Silva

# %%
spot['title']
# Out:
# 'Chess Buds'

# %%
spot['is_still_participant']
# Out:
# True

# %%
spot['thread_type']
# Out:
# 'RegularGroup'

# %%
spot['thread_path']
# Out:
# 'inbox/chessbuds_npjakt9u1g'

# %%
spot['magic_words']
# Out:
# []

# %%
spot['joinable_mode']['link']
# Out:
# ''

# %%
spot['joinable_mode']['mode']
# Out:
# 1

# %% [markdown]
# Note: I give up on things like this super easy. Mostly because I run into issues with mental energy to figure it out.
#
# I recognize it for what it is. Messages is where the important data is. How to tidy it up, because it's a list is what I struggled with. I have ChatGPT and, believe me, I was tempted to use it - not to copy/paste - but to gain a greater understanding of what I'm missing. There's a way to break the data out of a simple list - as I'm reading Hould's piece.
#
# But I would use it to determine activity in the group chat. Or unsent messages. Or reaction usage. But most of the data here is completely frivolous and any form of dissemination, beyond activity, is purely useless and any data scientist who tries to break anything other than activity is simply wasting their time.
#
# There is one circumstance - in Content - searching for a specific string within that string would be useful, or knowing how many messages were "bumped." In a way... knowing the time gap between messages would also be beneficial. But surely there are easier ways of doing these things... and again. I stand by my sentiment. There are elements of this data that serve no purpose whatsoever.
