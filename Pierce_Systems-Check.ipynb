# %% [markdown]
# # Systems Check
# ### Cadence Pierce
# ##### EMAT 62110
#
# Making a List
# - thing one
# 1. thing one
#
# _italics_ __bold__
#
# Add multi-level headings, ordered lists, and bold and italics text, and an image – In these cells describe what you hope to get out of this class.
#
# ## What I want out of the class
# - An understanding of Python to enable making my job that much easier.
# - An ability to build Python code to share with people in my profession to make their lives that much easier.
# - An understanding of Python to teach it to people in my profession to help expand its usage in sports comm.
# - Always remembering: _“I choose a lazy person to do a hard job. Because a lazy person will find an easy way to do it.” - Bill Gates_
# - __A chance to become a changemaker__
#
# ![Image of Me](data:image/jpeg;base64,...)

# %%
my_name =  "Cadence"
my_name

def give_name():
        print(my_name)

give_name()

def return_name():
        return my_name

new_name = return_name()
# Out:
# Cadence
