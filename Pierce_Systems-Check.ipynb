# %% [markdown]
# # Systems Check
# ### Cadence Pierce
# ##### EMAT 62110
#
# Making a List
# - thing one
# 1. thing one
#
# _italics_ __bold__

# %%
my_name =  "Cadence"
my_name

def give_name():
        print(my_name)

give_name()

def return_name():
        return my_name

new_name = return_name()
# Out:
# Cadence
